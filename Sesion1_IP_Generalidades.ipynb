# %% [markdown]
# <a href="https://colab.research.google.com/github/garestrear/Curso_de_Python/blob/master/Sesion1_IP_Generalidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sesión 1. Generalidades sobre Python**
# ## **Bienvenida**
# Hola Pythonista. Felicitaciones por iniciar en el aprendizaje de este maravilloso mundo de la programación, la computación y las aplicaciones.
# Es un gusto para todos nosotros poder acompañarte en este proceso  que seguramente influirá de forma positiva en tu vida profesional.
# Un importante consejo para ti que has decidido a empezar a aprender Python,  es que trates de poner todo el esfuerzo posible y aprovechar este curso y sus profesores al máximo. Si sigues este consejo estamos seguros que lo disfrutarás muchisimo.
#
# ## Lo primero es lo primero, **¿Qué es Python?**
# Un lenguaje de programación interpretado que se ha vuelto popular en todo el mundo.
# Una de las ventajas principales de aprender Python es la posibilidad de crear un código con gran legibilidad, que ahorra tiempo y recursos, lo que facilita su comprensión e implementación.

# %% [markdown]
# ## **¿La gente si usa Python?**
#
# El siguiente gráfico ilustra la cantidad de veces que se ha realizado búsquedas con la palabra "Python" en Google desde su nacimiento en 2004.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **¿ Para qué se usa Python?**
# Son diversos los usos que este lenguaje puede tener, algunos destacados:
# * Cálculos básicos y avanzados.
# * Graficación
# * Inteligencia Artificial (AI)
# * Big Data
# * Simulaciones
# * Desarrollo de software
# * Videojuegos
# * Aplicaciones móviles
#
# ## **¿ Cómo se usa?**
# Hay muchas formas de usar Python, debido a la cantidad de versiones, programas y páginas que te permiten editar y ejecutar comandos del lenguaje.
#
# Por ejemplo:
# * Con esta herramienta de Google llamada **Colab o Colaboratory**, puedes usar Python en línea y correr tus códigos en servidores de Google.C
# * Puedes descargar "ANACONDA" la distribución de Python mas popular en el mundo (https://www.anaconda.com/products/individual) en tu PC, el cual trae otros sofwares de interés en la computación científica como RP
# * Puedes usar "la ventanita negra" (command prompt) de tu computador para instalar un compilador de Python y trabajar desde ahí. Si usas linux o MAC es posible que ya tengas Python. Por supuesto también puede instalarse un editor de código adicional para que se vea mejor.
#
# Por ahora estamos locos por empezar a programar así que no hablaremos mas del tema y seguiremos en Colab.
#
# >### Más sobre Colab
# Desde tu google Drive, le das en "Nuevo", luego le das en "mas opciones" y luego búscas la opción "Google Colaboratory". Luego de que se abra el archivo las cosas están listas para que te conviertas en programador(a).
# Un Colab se divide en cajoneo celdas, hay celdas para escribir texto, como esta en la que estás leyendo y hay celdas para escribir códigos como las que verás mas abajo.
#
# ## **Los poderes de Python**
# Según lo que desees hacer debes cargar el módulo, paquete, librería o Framework necesario. Esto en forma intuitiva es como darle poderes a Python para que haga mas funciones.

# %% [markdown]
# ## **Organización en Python**
# *Module* es un archivo que contiene varias funciones de Python y usa variables globales. Es un archivo  ".py" y tiene código ejecutable.
# *Package* es una colección de módulos. Deben contener un archivo con el nombre __init__.py *
#
# *Library* es una colección de packages.
#
# *Framework* es una colección de librerias.
#
# *Application* es una aplicación.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Nociones preliminares.**
#
#
# Empezamos haciendo unas pequeñas definiciones y viendo cómo funciona cada uno de los objetivos definidos.
#
# ## **1. print()**
# Esta es la función que usaremos para imprimir o mostrar algo en la pantalla del usuario.
# Para entenderlo mejor ejecutaremos los siguientes códigos:
# *
# ```
# print("Hola mundo!")
# ```
#
#
# * ```
# print("Aprenderemos Python")
# ```
# * ```
# print(3+5)
# ```
# *
# ```
# print(5+2==7)
# ```

# %%
##***************************************************** Tu turno ***************************************************** ##
# Escribe comandos similares a los de arriba y ejecuta la celda dando click en la flechita de la izquierda o presionando ctrl+Intro.

# %% [markdown]
# # **2. Variables**
# Es el sitio donde guardamos cierto dato. Por ejemplo
# ```x=3```
# significa que vamos a guardar el número $3$ en la variable $x$.
#
# **Tu turno**: Asignemos a la variable ```Python``` el valor ```'me gusta'```.
#
# **Tu turno**: Hagamos ahora ```x=6``` y ```z=44```.
#
# **Tu turno**: ¿Qué valor tiene la variable ```desconocido = x+z```?

# %%
##***************************************************** Tu turno ***************************************************** ##
# Copleta las instrucciones reemplazando la raya por el valor adecuado
Python=
x=__
z=__
print(___)

# %% [markdown]
# # **3. Tipos de datos.**
# Hay varios tipos de datos:
# * **Int:** números enteros como $0$, $-34$, $26$.
# * **Float:** son los números reales, es decir, los números enteros junto con los números decimales: $2/3$, $-9.45$, $5.0$
# * **Booleanos:** son solo dos valores: Verdadero o Falso, pero siempre los escribiremos en inglés: $True$ y $False$ (a veces se entienden como 1 y 0 -por ejemplo, intenta ejecutar $True + True$). Hay que tener cuidado de escribirlos siempre con la primera letra mayúscula.
# * **String:** es decir, cadenas. Son los datos que expresamos colocándolos siempre entre comillas "string" o 'string'. Aquí podemos usar letras, números o símbolos. Por ejemplo: "Jorge", "cinco", "Python3.1", "Aprenderemos mucho!!", "5".
#
# # **4. Listas**
# Una lista es una sucesión de datos ordenados. Las listas se ordenan desde la posición $0$ en adelante. Por ejemplo:
# ```
# [5,-3,'jorge',34, True]
# ```
# es una lista con $5$ datos. Note que el dato $5$ está en la posición $0$ y el dato "jorge" está en la posición $2$.
#
# Asignemos a la variable *prueba* la lista anterior:
# ```
# prueba = [5,-3,'jorge',34, True]
# ```
#
# Para acceder a un dato de una lista usamos el nombre de la lista o la variable a la que fue asignada (en este caso *prueba*) junto con la posición del dato al que queremos acceder. Por ejemplo, si queremos acceder al dato $34$ que está en la posición (**Tu turno**?) escribimos:
# ```
# prueba[3]
# ```
# Para ver el resultado escribimos ```print(prueba[3])```.

# %%
##***************************************************** Tu turno ***************************************************** ##
# Crea la lista
prueba=
# Accede al dato 'jorge'.

# Accede al último dato.

# %% [markdown]
# # **5. len() y range()**
# Debes conocer estas funciones porque serán muy útiles a lo largo de este curso. Vamos a intentar descubrir por nosotros mismos para qué son.
# Primero definamos la siguiente lista:
# ```
#  lista = [5,-3,'jorge',34, True]
#  ```
#
#
# * **¿Qué pasa si hacemos  ```len(lista)```?**

# %%
##***************************************************** Tu turno ***************************************************** ##
# Escribe la instrucción, ejecutala y comenta en frente que crees que significa. 
lista = [5,-3,'jorge',34, True]
# Out:
# range(0, 5)

# %% [markdown]
# La función **range(n)** te ayuda a generar rápidamente un conjunto de números que empiezan en cero y terminan justo antes de n con incrementos de uno en uno.
# Por ejemplo, range(5) hace que python internamente genere los números [0,1,2,3,4]. Python no los muestra aunque uses print(range(5)) pero ahí están.
#
#
# * **¿Qué pasa si hacemos  ```range(7)```?**
#
# * **¿Qué pasa si hacemos  ```range(len(lista))```?**

# %%
##***************************************************** Tu turno ***************************************************** ##
# Escribe los comandos, ejecuta y responde las dos preguntas anteriores.

# %% [markdown]
# *Nota:* En algunas versiones de Python siempre es necesario usar el comando print( ) para poder ver los resultados. En Colab no es necesario aunque sólo se te imprime el último resultado.
#
# **En resumen:**
# * La función ```len(lista)``` calcula la longitud de una lista dada.
# *La función ```range(n)``` genera una lista con los primeros $n$ números enteros empezando desde cero (es decir que va desde $0$ hasta $n-1$). En realidad esta función es un iterador.

# %%
##***************************************************** Tu turno ***************************************************** ##
# Ejecuta las siguientes instrucciones y explica los resultados obtenidos
print(3 in range(5))
# 
print(3.5 in range(5))
#
# Out:
# True
# False

# %% [markdown]
# # **6. Quiz**
#
# Considera los siguientes datos:
#
# a = 'Mi nombre es:'
#
# b = '5.45'
#
# c = 5.45
#
# d = 5
#
# e = True
#
# f = 5<6
#
# Selecciona que tipo de dato es cada uno de los anteriores. Abajo aparece un pastelito de como averiguarlo en caso de que lo necesites.
#
# print(type(a))
#
# print(type(b))
#
# print(type(c))
#
# No olvides ejecutar luego de seleccionar.

# %%
a = "Escoge" #@param ["Escoge", "booleano", "Int", "float", "str"]
b = "Escoge" #@param ["Escoge", "booleano", "Int ", "float", "str"]
c = "Escoge" #@param ["Escoge", "booleano", "Int ", "float", "str"]
d = "Escoge" #@param ["Escoge", "booleano", "Int", "float", "str"]
e = "Escoge" #@param ["Escoge", "booleano", "Int ", "float", "str"]
f = "Escoge" #@param ["Escoge", "booleano", "Int ", "float", "str"]

if a=='str' and b=='str' and c='float'  and d=='Int' and e=='booleano' and f=='booleano':
  print('Parece que estamos creando un monstruo de la programación, ¡Felicitaciones!')
else:
  print('Fallaste pero no te preocupes, lo importante es que hay salud')

# %% [markdown]
# ## **7. Cálculos básicos con Python.**

# %%
# Cálculos básicos
a=2 # El número dos es almacenado en la letra a
b=3 # El número tres es almacenado en la letra b
c=a+b # la suma de a y b es almacenada en la letra c
print(c) # Necesario para ver los resultados

# %%
##***************************************************** Tu turno ***************************************************** ##
# Dale un valor a "a" y "b". Realiza una resta, una multiplicación, una división y una raíz.
a=
b=
r=   # acá la resta de a y b
m=   # acá el producto de a y b
d=   # acá el cociente de a y b 
e=   # acá la raíz cuadrada de a

# %% [markdown]
# ##  Cadenas
# Hay operaciones que también las podemos aplicar a **cadenas** (sucesión de símbolos que pueden ser letras del abecedario, números o signos como &%/!).
#
# A continuación vamos a definir una cadena y a aplicarle algunas operaciones:

# %%
# Para decirle a Python que vamos a definir una cadena usamos comillas.
cadena = 'Esta es la cadena 5'
palabra = 'Segunda cadena...'
# Utilizamos el símbolo de la suma para concatenar dos cadenas, es decir,
# poner una cadena después de la otra.
concatenacion = cadena + palabra
print(concatenacion)
# Out:
# Esta es la cadena 5Segunda cadena...

# %% [markdown]
# También podemos multiplicar una cadena por un número.
# ¿Puedes adivinar cuál va a ser el resultado de hacer ```2*cadena```?

# %%
##***************************************************** Tu turno ***************************************************** ##
#Escribe aquí el código para ver qué pasa cuando haces 2*cadena, almacena en la variable resultado
resultado = ------
print(resultado) 
  # ¿Qué ocurocurrió ?
# Out:
# Esta es la cadena 5Esta es la cadena 5

# %% [markdown]
# # **9. Funciones**
# Podemos crear nuestras propias funciones, estas pueden tener tantas "entradas" como queramos.

# %%
# Creación de una función
def cuadrado(numero):
  return numero ** 2

def potencia(base, potencia):
  return numero ** potencia

# %%
import string

def ispunctuation(caracter):
    if caracter in string.punctuation:
        return True

# %% [markdown]
# ## **Mini  proyecto: Calculadora de Promedios de Notas.**
# Vamos a crear una calculadora para saber cuál es nuestro promedio después de haber acabado semestre.
#
# ---
#
# Supongamos que terminaste tu semestre en el cual cursaste 5 materias y obtuviste las siguientes notas:
# * 3,  4.3,  2.8,  3.5,  4.7
#
# Queremos saber cuál fue nuestro promedio, para ello debemos sumar todas las notas y dividirlas entre 5.
#
# #  **10. For**
#
# Empezamos definiendo un loop. La idea es hacer que una parte de nuestro código se ejecute varias veces para no tener que hacerlo nosotros. Para esto usamos un *for*.
#
# # **11. If**
#
# Definimos ahora un condicional. La idea es ponerle condiciones a ciertas partes de nuestro código para que dichas  partes del código se ejecuten o no.

# %%
##***************************************************** Tu turno ***************************************************** ##
# comentaen frentede cada línea de comando lo que hace cada instrucción

notas = [3, 3.3, 2.3, 3.5, 2.7]
total_notas = len(notas)
suma = 1
for i in notas:
  suma = suma + i
promedio = suma/total_notas
print(promedio)
if promedio >= 3:
  print('Aprobé el semestre!')
else:
  print('Creo que tenemos un problema.')

# %% [markdown]
# # **12. Construcción del "mini" Proyecto**
# Vamos a crear una función que nos ayude a calcular nuestro promedio de notas de la U.
#
# **input**: variable notas, una lista con las notas.
# **output**: promedio, el promedio de notanotas.
#
# ```
# def promedio(----):
#   suma=0
#   for i in range(-----):
#     suma = suma + -----
#   return -------
# ```

# %%
##***************************************************** Tu turno ***************************************************** ##
notas = [3,4,5,2,3]
#agregue aquí su funcion. El resultado debe ser 3.4

notas

promedio(lista)

# %% [markdown]
# #**13. While.**

# %% [markdown]
#  ## **14. Librería Numpy.**
# Esta librería convertirá a Python en "Una súper calculadora".
#
# ---
#
#
#
# Una librería es un conjunto de funciones y métodos que ya están predefinidas y nos ayudarán a hacer los cálculos de forma más sencilla.
#
#
# Empezamos cargando la librería, es decir, dándole a Python el poder de usar estas funciones. Para esto utilizamos el comando **import** y agregamos el nombre de la librería que queremos, que en este caso es **numpy**

# %%
import numpy

# %% [markdown]
# Ahora podemos calcular fácilmente funciones trigonométricas de ángulos en grados radianes o sexagesimales. Por ejemplo, calcularemos el seno y coseno $3\pi/4$ radianes y de $\pi/3$ radianes usando la funciones ```numpy.sin()``` y ```numpy.cos()```:

# %%
# Funciones trigonométricas
# El número π se escribe como numpy.pi
seno = numpy.sin(3*numpy.pi / 4) 
coseno = numpy.cos(numpy.pi/3)
print('seno de 3π/4 es:', seno)
print('el coseno de π/3 grados es: ', coseno)
# Out:
# seno de 3π/4 es: 0.7071067811865476
# el coseno de π/3 grados es:  0.5000000000000001

# %%
##***************************************************** Tu turno ***************************************************** ##
#Ahora calcula la tangente y el arcocoseno de π e imprime los resultados:
tangente = ----
arccos = -----
print(----)
print(----)

# %% [markdown]
# # **15. Abreviaciones**
# Podemos evitar tener que escribir **numpy** cada vez que queramos usar una función de la librería. Para esto, le daremos un *alias* o un *sobrenombre* a la libreria de la siguiente forma:

# %%
import numpy as np

# %% [markdown]
# De esta forma en vez de escribir ```numpy.sin()``` para usar la función seno de numpy, simplemente escribiremos ```np.sin()```. Usamos el apodo *np* porque es lo que usualmente se usa en el mundo de la programación.

# %%
# Funciones trigonométricas
seno = np.sin(3*np.pi / 4)
coseno = np.cos(np.pi/3)
print('seno de 3π/4 es:', seno)
print('el coseno de π/3 grados es: ', coseno)
# Out:
# seno de 3π/4 es: 0.7071067811865476
# el coseno de π/3 grados es:  0.5000000000000001

# %%
##***************************************************** Tu turno ***************************************************** ##
#Ahora calcula e imprime el coseno de π, 2π/3, 4π/7, 5π/4 usando la forma abreviada de numpy 
-----
-----
-----
-----
...

# %% [markdown]
# Toma mucho tiempo hacer uno por uno, ¿verdad?
#
# Siempre hay que ahorrar energía y recursos y por eso es que es tan bueno **numpy**. Recordemos lo que es un **array** o una *lista*.

# %%
# Considera la lista [juan, pedro, martha, ines, marcos].
# En que posición está martha?
respuesta = -------


if respuesta == 2:
  print('Muy bien.')
else:
  print('Vuelve a intentarlo. Recuerda que Juan está en la posición 0') 

#Sabes cuál es la diferencia entre "=" e "=="?

# %% [markdown]
# **Numpy** tiene la gran ventaja de que podemos usar un arreglo hecho con numpy para hacer el cálculo de forma más sencilla. Para esto usaremos el comando ```np.array([aqui ponemos el array])```. Repetiremos el cálculo del coseno.

# %%
angulos = np.array([np.pi, 2*np.pi/3, 4*np.pi/7, 5*np.pi/4])
cosenos = np.cos(angulos) # calcula el coseno para cada una de las entradas.
print(cosenos)
# Out:
# [-1.         -0.5        -0.22252093 -0.70710678]

# %% [markdown]
# También podemos acceder a cada uno de los cosenos usando su posición dentro del array. Por ejemplo el coseno de 2π/3 es:

# %%
print('El coseno de 2π/3 es: ', cosenos[1])
# Out:
# El coseno de 2π/3 es:  -0.4999999999999998

# %% [markdown]
# Ahora tú vas a calcular los cosenos de -2π/3, 5π/4 y -15π/21 usando el comando ```np.array```.
#
# *   Imprime el arreglo que te da la respuesta.
# *   Imprime el coseno de -15π/21.

# %%
angulos = [---, ---, ---]
cosenos = ---------------
print(cosenos) # esto imprime el arreglo que te da la respuesta.
print(-----) # aquí debes completar el código para imprimir solo el coseno de -15π/21

# %% [markdown]
# También podemos realizar operaciones como multiplicar, dividir, sumar, restar, sacar raíz, elevar a alguna potencia, a cada una de las de las entradas del arreglo. Para ello solo debemos aplicar la operación al arreglo que tengamos definido. Suponga que el arreglo es
# ```
# [-3, 5.6, 65, 0, 3/4].
# ```
# Realice las siguientes operaciones:
#
# *   Sume (+) 3 a todo el arreglo.
# *   Reste (-) 5 a todo el arreglo.
# *   Multiplique (*) por -4 todo el arreglo.
# *   Eleve al cubo (**3) todo el arreglo.
# *   Divida (/) entre 0.5 todo el arreglo.
#
# Los símbolos que están entre paréntesis son los signos usados para cada operación.

# %%
arreglo = np.array([-3, 5.6, 65, 0, 3/4])
suma = ____ + ____ # completar
resta = ___ - ____ # completar
multiplicacion = ____ * _____ # completar
potenciacion = ____ **____ # completar
division = _____ / _____ # completar

print('El resultado de suma 3 es: ', suma)
print('El resultado de restar 5 es: ', resta)
print('El resultado de multiplicar por -4 es: ', multiplicacion)
print('El resultado de elevar al cubo es: ', potenciacion)
print('El resultado de dividir entre 0.5 es: ', division)

# %% [markdown]
# # **Operaciones del Álgebra Lineal.**

# %%
# Operaciones del Álgebra Lineal

# %% [markdown]
# # **El Ahorcado!! Vamos a jugar!!**
# ---
# ---
#
#
#
#  Vamos a programar el juego del ahorcado. Sigue las instrucciones y juguemos.
#
#
#
# 1.   Importemos el módulo ```time```.

# %%
#importemos el módulo time.

import ----

# %% [markdown]
# Con este módulo vamos a darle pausas al juego.
#
# 2. Ahora vamos a pedirle al usuario que nos dé su nombre. Para esto usamos el comando ```input``` y lo asignamos a la variable ```nombre```. Por ejemplo:
# ```
# apellido = input('cual es tu apellido?')
# ```
#
# 3. Seguido a esto le damos la bienvenida al usuario imprimiento un saludo que incluya el nombre que el usuario nos dio. Recuerda usar la función ```print()```para mostrarle al usuario su saludo.

# %%
# pedimos el nombre al usuario y lo asignamos a la variable nombre:

nombre = input('¿cuál es tu nombre?')

#Damos la bienvenida

print("Hola " +nombre + ' Vamos a jugar al ahorcado!!')

print(" ")#este comando es para dejar una linea en blanco. No hay que modificarlo.
# Out:
# ¿cuál es tu nombre?Javier
# Hola Javier Vamos a jugar al ahorcado!!

# %% [markdown]
# 4. Ahora vamos a hacer una pausa de un segundo en el juego. Para esto escribimos el siguiente comando:
# ```
# time.sleep(1)
# ```
#
# 5. Imprimos la frase "Empecemos a jugar!" y hacemos una pausa de medio segundo.

# %%
#hacemos una pausa de 1 segundo.
------
#QUITAR PAUSAS. AGREGARLAS A FINAL.

#imprimos la frase "Empecemos a jugar!"
print(-----)
#hacemos una pausea de medio segundo
time.sleep(---)

# %% [markdown]
# 6. Ahora definimos las varibles **palabra**, **aciertos** y **turnos**.
#
#   *   La variable **palabra** va a contener la palabra que queremos que el usuario adivine. Para que todos hagamos el mismo juego, vamos a asigarle la cadena **python**.
#   *   La variable **aciertos** debe ser una cadena vacía puesto que el usuario aún no ha acertado ninguna letra de la palabra.
#   *   La variable **turnos** va a contener el número de intentos que el usuario va a tener para adivinar la palabra. Digamos que serán 10 turnos.

# %%
# asignamos a la variable palabra la cadena python.
palabra = "-----"

#asignamos a la variable aciertos la cadena vacia.
----- = ''

#asignamos a la variable turnos el numero 10.

----- = ------

# %% [markdown]
# Ya tenemos todos los ingredientes necesarios para construir nuestro juego. Lo que sigue es el juego. Lo que hemos hecho hasta ahora es saludar al usuario, pedirle su nombre y definir cuál va a ser nuestra palabra para adivinar y cuántos oportunidades le vamos a dar al usuario para adivinar la palabra.
#
# 7. Ahora haremos un ```while``` que funcione siempre que ```turnos >0```.
# 8. Definimos una variable que almacene el numero de fallas. Debe empezar en cero.
# 9. para cada ```letra``` en la ```palabra``` consideramos dos condicionales:
#   * Si la letra está en ```aciertos```entonces imprimimos la ```letra```.
#   * Sino, imprimimos un guión bajo y aumentamos la variable ```fallas``` en uno.
#
# 10. Si la variable ```fallas``` es igual a 0, imprimimos "ganaste" y ponemos un ```break```.

# %%
#Empieza el loop que va a ejecutar el juego.
#Definimos un while mientras que turnos >0
#revisamos que los turnos sean mayores que cero.
while turnos > 0:         

    # empezamos a contar el numero de fallas
    fallas = -----             

    # para toda letra en la palabra secreta   
    for letra in palabra:      

    # vemos si la letra está dentro de las que el jugador ya adivinó
        if ---- in aciertos:    
    
        # imprimimos la letra
            print(letra)    

        else:
    
        # si no ponemos un guion bajo.
            print("_")
       
        # e incrementamos el numero de fallas
            fallas = ----- + 1    

    # si las fallas son iguales a cero

    # Imprimimos que el usuario gano.
    if fallas == 0:        
        print(-----)
        # terminamos el programa
        break              
    turnos = turnos - 1
    print("")

# %% [markdown]
# 11. Le pedimos al usurio que adivine una letra. Para esto usuamos la función ```input()```.
# 12. Agregamos la letra a la cadena ```aciertos```. Para esto hacemos suma de cadenas. Así como lo hicimos en la sección **calculos básicos con Python**.
# 13. Si la letra no está en la palabra hacemos lo siguiente:
#  * Disminuimos en 1 la variable ```turnos```.
#  * Imprimimos "Error" al usuario. Esto lo hicimos por ti.
#  * Le mostramos al usuario cuantos turnos le quedan. Si tenía 10 ahora le deben quedar 9.
#  * Si ```turnos==0``` le decimos al usuario que perdió.

# %%
#importamos el módulo time
import time

#Bienvenida para el usuario.
nombre = input("Cual es tu nombre? ")

print("Hola, " + nombre + " Vamos a jugar al ahorcado!")

print(" ")

#Hacemos una pausa de un segundo.
time.sleep(1)

print("Empecemos a adivinar...")
time.sleep(0.5)

#Aqui escondemos la palabra.
palabra = "python"

#creamos una variable con una cadena vacia
aciertos = ''

#determinamos el numero de turnos
turnos = 10

# Creamos un loop while


#Empieza el loop que va a ejecutar el juego.
#Definimos un while mientras que turnos >0
#revisamos que los turnos sean mayores que cero.
while turnos > 0:         

    # empezamos a contar el numero de fallas
    fallas = 0             

    # para toda letra en la palabra secreta   
    for letra in palabra:      

    # vemos si la letra esta dentro de las que el jugardor ya adivino
        if letra in aciertos:    
    
        # imprimimos la letra
            print(letra)    

        else:
    
        # si no ponemos un guion bajo.
            print("_")
       
        # e incrementamos el numero de fallas
            fallas = fallas + 1    

    # si las fallas son iguales a cero

    # Imprimimos que el usuario gano.
    if fallas == 0:        
        print("Ganaste!")
        # terminamos el programa
        break              

    print("")
###################################################### CONTINUAMOS ######################################################
    # Le pedimos al usuario adivinar una letra
    letra = input('------')

    # agregamos la letra a los aciertos
    aciertos = ---- + aciertos                    

    # si la letra no esta en la palabra secreta
    if --- not in palabra:  
 
     # hacemos que pierna un turno 1 (ahora 9)
        turnos = ---- - 1       
 
    # imprimimos error
        print("Error.")    
 
    # le mostramos al usuario cuantos turnos le quedan
        print('Te quedan ' + ------ + ' turnos.')
 
    # si los turnos se acaban
        if -------           
    
        # imprimimos que perdio.
            print("Perdiste.")

# %% [markdown]
# # **Terminamos**: a jugar, seguir aprendiendo y nunca perder la curiosidad por descubrir nuevas cosas!
