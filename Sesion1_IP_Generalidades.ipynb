# %% [markdown]
# <a href="https://colab.research.google.com/github/garestrear/Curso_de_Python/blob/master/Sesion1_IP_Generalidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sesión 1. Generalidades sobre Python
# ## ¿Qué es Python?
# Un lenguaje de programación interpretado que se ha vuelto popular en todo el mundo.
# Una de las ventajas principales de aprender Python es la posibilidad de crear un código con gran legibilidad, que ahorra tiempo y recursos, lo que facilita su comprensión e implementación.
# El siguiente gráfico muestra la cantidad de veces que se han realizado búsquedas en google que involucran la palabra "Python"  desde el nacimiento de Google en 2004.
#
# ![image.png](data:image/png;base64,...)
#
# ## ¿ Para qué se usa Python?
# Son diversos los usos que este lenguaje puede tener, algunos destacados:
# * Cálculos básicos y avanzados.
# * Graficación
# * Inteligencia Artificial (AI)
# * Big Data
# * Simulaciones
# * Desarrollo de software
#
# ## ¿ Cómo se usa?
# Puedes usar Python en línea, por ejemplo con esta herramienta de Google llamada Colab. Según lo que desees hacer debes cargar la librería adecuada, esto en forma intitiva es como darle poderes a Python para que haga mas funciones. A mas lbrerias más poder, pero cuidado, algunos poderes podrían no ser compatibles.

# %% [markdown]
# ## cálculos básicos con Python

# %%
# Cálculos básicos
a=2 # El número dos es almacenado en la letra a
b=3 # El número tres es almacenado en la letra b
c=a+b # la suma de a y b es almacenada en la letra c
print(c) # Necesario para ver los resultados

# %%
# Tu turno. Dale un valos a "a" a "b" y realiza una resta, una multiplicación, una división, una raíz y un logaritmo.
a=
b=
r=   # acá la resta de a y b
m=   #acá el producto de a y b
d=   #acá el cociente de ay b

# %%
# Creación de una función

# %%
# Listas o arreglos, longitudes y range append

# %%
# Cadena de caracteres y concatenar

# %%
# Ciclos y condicionales (any, all, and)

# %%
# input y convertir a el input en núeo o str

# %%
# Importar paquetería

# %% [markdown]
# ## Librería Numpy
# Esta librería convertirá a Python en "Una super calculadora".

# %%
# Funciones trigonométricas

# %%
# Operaciones del Álgebra Lineal
